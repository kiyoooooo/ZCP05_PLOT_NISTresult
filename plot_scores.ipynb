# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

# %%
output1to1_10to22_value0, output1to1_10to22_value1, output1to1_10to22_value2 = np.loadtxt("./1to1output/10to22bit/score_summary.txt", skiprows=1, unpack=True)
output1to1_13to19_value0, output1to1_13to19_value1, output1to1_13to19_value2 = np.loadtxt("./1to1output/13to19bit/score_summary.txt", skiprows=1, unpack=True)

output1to2_10to22_value0, output1to2_10to22_value1, output1to2_10to22_value2 = np.loadtxt("./1to2output/10to22bit/score_summary.txt", skiprows=1, unpack=True)
output1to2_13to19_value0, output1to2_13to19_value1, output1to2_13to19_value2 = np.loadtxt("./1to2output/13to19bit/score_summary.txt", skiprows=1, unpack=True)

output2to1_10to22_value0, output2to1_10to22_value1, output2to1_10to22_value2 = np.loadtxt("./2to1output/10to22bit/score_summary.txt", skiprows=1, unpack=True)
output2to1_13to19_value0, output2to1_13to19_value1, output2to1_13to19_value2 = np.loadtxt("./2to1output/13to19bit/score_summary.txt", skiprows=1, unpack=True)

output1to36_10to22_value0, output1to36_10to22_value1, output1to36_10to22_value2 = np.loadtxt("./1to36output/10to22bit/score_summary.txt", skiprows=1, unpack=True)
output1to36_13to19_value0, output1to36_13to19_value1, output1to36_13to19_value2 = np.loadtxt("./1to36output/13to19bit/score_summary.txt", skiprows=1, unpack=True)


output36to36_10to22_value0, output36to36_10to22_value1, output36to36_10to22_value2 = np.loadtxt("./36to36output/10to22bit/score_summary.txt", skiprows=1, unpack=True)
output36to36_13to19_value0, output36to36_13to19_value1, output36to36_13to19_value2 = np.loadtxt("./36to36output/13to19bit/score_summary.txt", skiprows=1, unpack=True)

output36to64_10to22_value0, output36to64_10to22_value1, output36to64_10to22_value2 = np.loadtxt("./36to64output/10to22bit/score_summary.txt", skiprows=1, unpack=True)
output36to64_13to19_value0, output36to64_13to19_value1, output36to64_13to19_value2 = np.loadtxt("./36to64output/13to19bit/score_summary.txt", skiprows=1, unpack=True)

output64to36_10to22_value0, output64to36_10to22_value1, output64to36_10to22_value2 = np.loadtxt("./64to36output/10to22bit/score_summary.txt", skiprows=1, unpack=True)
output64to36_13to19_value0, output64to36_13to19_value1, output64to36_13to19_value2 = np.loadtxt("./64to36output/13to19bit/score_summary.txt", skiprows=1, unpack=True)

output64to64_10to22_value0, output64to64_10to22_value1, output64to64_10to22_value2 = np.loadtxt("./64to64output/10to22bit/score_summary.txt", skiprows=1, unpack=True)
output64to64_13to19_value0, output64to64_13to19_value1, output64to64_13to19_value2 = np.loadtxt("./64to64output/13to19bit/score_summary.txt", skiprows=1, unpack=True)

# %%
data_axis0 = np.arange(0, 5000001, 500000)
print(data_axis0)
# Out:
# [      0  500000 1000000 1500000 2000000 2500000 3000000 3500000 4000000
#  4500000 5000000]

# %%
fig = plt.figure(figsize=(4, 6))
ax = fig.add_subplot(111)
ax.plot(data_axis0, output1to1_10to22_value0, "o-", color="k", label="output1to1_10to22")
ax.plot(data_axis0, output2to1_10to22_value0, "x-", color="g", label="output2to1_10to22")
ax.plot(data_axis0, output1to2_10to22_value0, "d-", color="r", label="output1to2_10to22")
ax.plot(data_axis0, output1to36_10to22_value0, "s-", color="b", label="output1to36_10to22")

#ax.set_xlim(-0.5, 5.5)
ax.set_ylim(0, 15)
ax.set_xlabel("Number of Learning Count")
ax.set_ylabel("No. of tests passed")
ax.legend(loc="upper right")
plt.show()
fig.savefig('output_low_10to22.png')

# %%
fig = plt.figure(figsize=(4, 6))
ax = fig.add_subplot(111)
ax.plot(data_axis0, output1to1_13to19_value0, "o-", color="k", label="output1to1_13to19")
ax.plot(data_axis0, output2to1_13to19_value0, "x-", color="g", label="output2to1_13to19")
ax.plot(data_axis0, output1to2_13to19_value0, "d-", color="r", label="output1to2_13to19")
ax.plot(data_axis0, output1to36_13to19_value0, "s-", color="b", label="output1to36_13to19")

#ax.set_xlim(-0.5, 5.5)
ax.set_ylim(0, 15)
ax.set_xlabel("Number of Learning Count")
ax.set_ylabel("No. of tests passed")
ax.legend(loc="upper right")
plt.show()
fig.savefig('output_low_13to19.png')

# %%
fig = plt.figure(figsize=(4, 6))
ax = fig.add_subplot(111)
ax.plot(data_axis0, output36to36_10to22_value0, "o-", color="k", label="output36to36_10to22")
ax.plot(data_axis0, output64to36_10to22_value0, "x-", color="g", label="output64to36_10to22")
ax.plot(data_axis0, output36to64_10to22_value0, "d-", color="r", label="output36to64_10to22")
ax.plot(data_axis0, output64to64_10to22_value0, "s-", color="b", label="output64to64_10to22")

#ax.set_xlim(-0.5, 5.5)
ax.set_ylim(0, 15)
ax.set_xlabel("Number of Learning Count")
ax.set_ylabel("No. of tests passed")
ax.legend(loc="upper right")
plt.show()
fig.savefig('output_mid_10to22.png')

# %%
fig = plt.figure(figsize=(4, 6))
ax = fig.add_subplot(111)
ax.plot(data_axis0, output36to36_13to19_value0, "o-", color="k", label="output36to36_13to19")
ax.plot(data_axis0, output64to36_13to19_value0, "x-", color="g", label="output64to36_13to19")
ax.plot(data_axis0, output36to64_13to19_value0, "d-", color="r", label="output36to64_13to19")
ax.plot(data_axis0, output64to64_13to19_value0, "s-", color="b", label="output64to64_13to19")

#ax.set_xlim(-0.5, 5.5)
ax.set_ylim(0, 15)
ax.set_xlabel("Number of Learning Count")
ax.set_ylabel("No. of tests passed")
ax.legend(loc="upper right")
plt.show()
fig.savefig('output_mid_13to19.png')
